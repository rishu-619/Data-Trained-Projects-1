# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %%
brain_head=pd.read_csv('brainhead.csv')
brain_head
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# 5         1          1             3585                 1300
# 6         1          1             3785                 1400
# 7         1          1             3559                 1255
# 8         1          1             3613                 1355
# 9         1          1             3982                 1375
# 10        1          1             3443                 1340
# 11        1          1             3993                 1380
# 12        1          1             3640                 1355
# 13        1          1             4208                 1522
# 14        1          1             3832                 1208
# 15        1          1             3876                 1405
# 16        1          1             3497                 1358
# 17        1          1             3466                 1292
# 18        1          1             3095                 1340
# 19        1          1             4424                 1400
# 20        1          1             3878                 1357
# 21        1          1             4046                 1287
# 22        1          1             3804                 1275
# 23        1          1             3710                 1270
# 24        1          1             4747                 1635
# 25        1          1             4423                 1505
# 26        1          1             4036                 1490
# 27        1          1             4022                 1485
# 28        1          1             3454                 1310
# 29        1          1             4175                 1420
# ..      ...        ...              ...                  ...
# 180       2          1             3689                 1290
# 181       2          1             3158                 1100
# 182       2          1             4005                 1280
# 183       2          1             3181                 1175
# 184       2          1             3479                 1160
# 185       2          1             3642                 1205
# 186       2          1             3632                 1163
# 187       2          2             3069                 1022
# 188       2          2             3394                 1243
# 189       2          2             3703                 1350
# 190       2          2             3165                 1237
# 191       2          2             3354                 1204
# 192       2          2             3000                 1090
# 193       2          2             3687                 1355
# 194       2          2             3556                 1250
# 195       2          2             2773                 1076
# 196       2          2             3058                 1120
# 197       2          2             3344                 1220
# 198       2          2             3493                 1240
# 199       2          2             3297                 1220
# 200       2          2             3360                 1095
# 201       2          2             3228                 1235
# 202       2          2             3277                 1105
# 203       2          2             3851                 1405
# 204       2          2             3067                 1150
# 205       2          2             3692                 1305
# 206       2          2             3402                 1220
# 207       2          2             3995                 1296
# 208       2          2             3318                 1175
# 209       2          2             2720                 9556
#
# [210 rows x 4 columns]

# %%
#--->>>> Doing EDA

# %%
brain_head.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
brain_head.tail()
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 205       2          2             3692                 1305
# 206       2          2             3402                 1220
# 207       2          2             3995                 1296
# 208       2          2             3318                 1175
# 209       2          2             2720                 9556

# %%
df=pd.DataFrame(data=brain_head)
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# 5         1          1             3585                 1300
# 6         1          1             3785                 1400
# 7         1          1             3559                 1255
# 8         1          1             3613                 1355
# 9         1          1             3982                 1375
# 10        1          1             3443                 1340
# 11        1          1             3993                 1380
# 12        1          1             3640                 1355
# 13        1          1             4208                 1522
# 14        1          1             3832                 1208
# 15        1          1             3876                 1405
# 16        1          1             3497                 1358
# 17        1          1             3466                 1292
# 18        1          1             3095                 1340
# 19        1          1             4424                 1400
# 20        1          1             3878                 1357
# 21        1          1             4046                 1287
# 22        1          1             3804                 1275
# 23        1          1             3710                 1270
# 24        1          1             4747                 1635
# 25        1          1             4423                 1505
# 26        1          1             4036                 1490
# 27        1          1             4022                 1485
# 28        1          1             3454                 1310
# 29        1          1             4175                 1420
# ..      ...        ...              ...                  ...
# 180       2          1             3689                 1290
# 181       2          1             3158                 1100
# 182       2          1             4005                 1280
# 183       2          1             3181                 1175
# 184       2          1             3479                 1160
# 185       2          1             3642                 1205
# 186       2          1             3632                 1163
# 187       2          2             3069                 1022
# 188       2          2             3394                 1243
# 189       2          2             3703                 1350
# 190       2          2             3165                 1237
# 191       2          2             3354                 1204
# 192       2          2             3000                 1090
# 193       2          2             3687                 1355
# 194       2          2             3556                 1250
# 195       2          2             2773                 1076
# 196       2          2             3058                 1120
# 197       2          2             3344                 1220
# 198       2          2             3493                 1240
# 199       2          2             3297                 1220
# 200       2          2             3360                 1095
# 201       2          2             3228                 1235
# 202       2          2             3277                 1105
# 203       2          2             3851                 1405
# 204       2          2             3067                 1150
# 205       2          2             3692                 1305
# 206       2          2             3402                 1220
# 207       2          2             3995                 1296
# 208       2          2             3318                 1175
# 209       2          2             2720                 9556
#
# [210 rows x 4 columns]

# %%
df.shape
# Out:
# (210, 4)

# %%
df.dtypes
# Out:
# Gender                 int64
# Age Range              int64
# Head Size(cm^3)        int64
# Brain Weight(grams)    int64
# dtype: object

# %%
df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  210.000000  210.000000       210.000000           210.000000
# mean     1.361905    1.476190      3665.500000          1334.971429
# std      0.481700    0.500626       360.945081           581.556383
# min      1.000000    1.000000      2720.000000          1022.000000
# 25%      1.000000    1.000000      3403.000000          1220.500000
# 50%      1.000000    1.000000      3643.000000          1290.000000
# 75%      2.000000    2.000000      3899.000000          1359.500000
# max      2.000000    2.000000      4747.000000          9556.000000

# %%
df.isnull().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df['Head Size(cm^3)'].plot.box()

# %%
df['Brain Weight(grams)'].plot.box()

# %%
df.plot(kind='box',subplots=True,layout=(2,5))
plt.show()

# %%
df[2:6]
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590
# 5       1          1             3585                 1300

# %%
plt.xlabel("Head Size(cm^3)")
plt.ylabel("Brain Weight(grams)")
plt.scatter(x,y)

# %%
def dataplot():
    plt.xlabel("Head Size(cm^3)")
    plt.ylabel("Brain Weight(grams)")
    plt.scatter(x,y)

# %%
dataplot()
