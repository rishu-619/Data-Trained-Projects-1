# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('claims.csv')
data=pd.DataFrame(data=data)
data
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# 5     OC83172      US         IA      Iowa    825.629780      Yes     Basic
# 6     XZ87318      US         IA      Iowa    538.089864      Yes     Basic
# 7     CF85061      US         NE  Nebraska    721.610031       No   Premium
# 8     DY87989      US         IA      Iowa   2412.750402      Yes     Basic
# 9     BQ94931      US         IA      Iowa    738.817808       No  Extended
# 10    SX51350      US         MO  Missouri    473.899202       No     Basic
# 11    VQ65197      US         MO  Missouri    819.719708       No     Basic
# 12    DP39365      US         MO  Missouri    879.879700       No   Premium
# 13    SJ95423      US         NE  Nebraska    881.901893      Yes     Basic
# 14    IL66569      US         MO  Missouri    538.443166       No     Basic
# 15    BW63560      US         IA      Iowa    746.313938       No     Basic
# 16    FV94802      US         OK  Oklahoma    256.686782       No     Basic
# 17    OE15005      US         MO  Missouri    394.524160       No     Basic
# 18    WC83389      US         IA      Iowa    571.033311       No     Basic
# 19    FL50705      US         MO  Missouri    816.261705       No   Premium
# 20    ZK25313      US         IA      Iowa    287.205127       No     Basic
# 21    SV62436      US         KS    Kansas    304.179156       No  Extended
# 22    YH23384      US         NE  Nebraska   2412.750402      Yes     Basic
# 23    TZ98966      US         OK  Oklahoma    245.019100       No     Basic
# 24    HM55802      US         MO  Missouri    239.210789       No     Basic
# 25    FS42516      US         IA      Iowa    580.206598       No     Basic
# 26    US89481      US         MO  Missouri    394.637208       No   Premium
# 27    HO30839      US         KS    Kansas    534.691658       No  Extended
# 28    GE62437      US         NE  Nebraska   1290.256014       No   Premium
# 29    EJ77678      US         IA      Iowa    323.536047       No  Extended
# ...       ...     ...        ...       ...           ...      ...       ...
# 9104  LM97847      US         MO  Missouri    261.513922       No     Basic
# 9105  IK96366      US         MO  Missouri    555.139817       No  Extended
# 9106  SJ86522      US         MO  Missouri    682.704442       No     Basic
# 9107  UU42868      US         MO  Missouri    561.968908      Yes   Premium
# 9108  GX11087      US         MO  Missouri    390.702875       No     Basic
# 9109  JR41742      US         MO  Missouri    362.287212       No     Basic
# 9110  RA89822      US         MO  Missouri   3461.137896      Yes     Basic
# 9111  IJ25462      US         MO  Missouri    284.552093       No     Basic
# 9112  ZP86347      US         MO  Missouri    550.057741       No  Extended
# 9113  HO82823      US         MO  Missouri    335.853294       No  Extended
# 9114  EA54906      US         MO  Missouri    750.166132       No  Extended
# 9115  BC64697      US         MO  Missouri   1166.398572       No   Premium
# 9116  VV68726      US         MO  Missouri    513.339776       No     Basic
# 9117  QR91631      US         MO  Missouri    873.209053       No     Basic
# 9118  OT56964      US         MO  Missouri    942.425684       No     Basic
# 9119  YX35990      US         MO  Missouri    547.955508      Yes     Basic
# 9120  RN61682      US         MO  Missouri    211.473847       No     Basic
# 9121  BB10681      US         MO  Missouri    414.064865       No  Extended
# 9122  FH43628      US         MO  Missouri   2546.482059      Yes  Extended
# 9123  WZ45103      US         MO  Missouri    567.805017      Yes  Extended
# 9124  CB59349      US         MO  Missouri   1626.158550       No  Extended
# 9125  RX91025      US         MO  Missouri   1987.226200       No   Premium
# 9126  AC13887      US         MO  Missouri    462.899533       No     Basic
# 9127  TF56202      US         MO  Missouri    503.216550       No     Basic
# 9128  YM19146      US         MO  Missouri    410.039853       No   Premium
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#                  Education Effective To Date EmploymentStatus  ...  \
# 0                 Bachelor           2/24/11         Employed  ...
# 1                 Bachelor           1/31/11       Unemployed  ...
# 2                 Bachelor           2/19/11         Employed  ...
# 3                 Bachelor           1/20/11       Unemployed  ...
# 4                 Bachelor            2/3/11         Employed  ...
# 5                 Bachelor           1/25/11         Employed  ...
# 6                  College           2/24/11         Employed  ...
# 7                   Master           1/18/11       Unemployed  ...
# 8                 Bachelor           1/26/11    Medical Leave  ...
# 9                  College           2/17/11         Employed  ...
# 10                 College           2/21/11       Unemployed  ...
# 11                 College            1/6/11       Unemployed  ...
# 12                  Master            2/6/11         Employed  ...
# 13    High School or Below           1/10/11         Employed  ...
# 14                 College           1/18/11         Employed  ...
# 15                Bachelor           1/17/11         Employed  ...
# 16    High School or Below            2/6/11    Medical Leave  ...
# 17                 College            1/5/11    Medical Leave  ...
# 18                 College           2/27/11         Employed  ...
# 19    High School or Below           1/14/11         Employed  ...
# 20    High School or Below           2/19/11         Employed  ...
# 21                Bachelor           1/21/11         Disabled  ...
# 22                Bachelor           1/26/11    Medical Leave  ...
# 23                Bachelor           2/24/11       Unemployed  ...
# 24                Bachelor            2/5/11         Disabled  ...
# 25                 College           1/29/11         Employed  ...
# 26                Bachelor           2/28/11       Unemployed  ...
# 27                  Master           2/12/11         Disabled  ...
# 28                 College            2/2/11         Employed  ...
# 29                  Master            2/7/11         Employed  ...
# ...                    ...               ...              ...  ...
# 9104               College            1/9/11         Employed  ...
# 9105               College           2/22/11         Employed  ...
# 9106  High School or Below           1/12/11       Unemployed  ...
# 9107  High School or Below           1/26/11       Unemployed  ...
# 9108  High School or Below           1/28/11       Unemployed  ...
# 9109               College           1/25/11       Unemployed  ...
# 9110  High School or Below           1/14/11         Employed  ...
# 9111              Bachelor            2/7/11         Employed  ...
# 9112               College           2/12/11         Employed  ...
# 9113              Bachelor            1/6/11         Employed  ...
# 9114  High School or Below           2/23/11         Employed  ...
# 9115               College           2/17/11       Unemployed  ...
# 9116  High School or Below           1/26/11         Disabled  ...
# 9117  High School or Below           1/20/11         Employed  ...
# 9118                Master           2/10/11         Employed  ...
# 9119                Master           1/13/11         Employed  ...
# 9120              Bachelor           2/19/11       Unemployed  ...
# 9121               College           1/17/11       Unemployed  ...
# 9122               College            2/1/11          Retired  ...
# 9123              Bachelor           1/19/11       Unemployed  ...
# 9124                Master           1/20/11         Employed  ...
# 9125  High School or Below           1/31/11       Unemployed  ...
# 9126              Bachelor            1/9/11       Unemployed  ...
# 9127               College           2/12/11         Employed  ...
# 9128               College            1/6/11         Employed  ...
# 9129              Bachelor           2/10/11         Employed  ...
# 9130               College           2/12/11         Employed  ...
# 9131              Bachelor            2/6/11       Unemployed  ...
# 9132               College            2/3/11         Employed  ...
# 9133               College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 0                                5                          0
# 1                               42                          0
# 2                               38                          0
# 3                               65                          0
# 4                               44                          0
# 5                               94                          0
# 6                               13                          0
# 7                               68                          0
# 8                                3                          0
# 9                                7                          0
# 10                               5                          0
# 11                              87                          0
# 12                              82                          2
# 13                              25                          1
# 14                              10                          2
# 15                              50                          1
# 16                               7                          0
# 17                              59                          0
# 18                               1                          0
# 19                              21                          0
# 20                              21                          0
# 21                              49                          0
# 22                               3                          0
# 23                              44                          3
# 24                              91                          0
# 25                               1                          0
# 26                              47                          0
# 27                              64                          0
# 28                              54                          2
# 29                              44                          1
# ...                            ...                        ...
# 9104                            59                          0
# 9105                            77                          3
# 9106                            26                          0
# 9107                             5                          0
# 9108                             8                          0
# 9109                            52                          0
# 9110                            59                          0
# 9111                            44                          1
# 9112                            60                          0
# 9113                            48                          0
# 9114                            86                          0
# 9115                            34                          0
# 9116                            59                          0
# 9117                            52                          0
# 9118                            11                          0
# 9119                            30                          1
# 9120                            69                          5
# 9121                            35                          2
# 9122                            66                          0
# 9123                            44                          0
# 9124                            42                          0
# 9125                            35                          0
# 9126                            21                          0
# 9127                            48                          0
# 9128                            58                          0
# 9129                            89                          0
# 9130                            28                          0
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#      Number of Policies     Policy Type        Policy  Claim Reason  \
# 0                     1  Corporate Auto  Corporate L3     Collision
# 1                     8   Personal Auto   Personal L3  Scratch/Dent
# 2                     2   Personal Auto   Personal L3     Collision
# 3                     7  Corporate Auto  Corporate L2     Collision
# 4                     1   Personal Auto   Personal L1     Collision
# 5                     2   Personal Auto   Personal L3          Hail
# 6                     9  Corporate Auto  Corporate L3     Collision
# 7                     4  Corporate Auto  Corporate L3     Collision
# 8                     2  Corporate Auto  Corporate L3     Collision
# 9                     8    Special Auto    Special L2          Hail
# 10                    3   Personal Auto   Personal L3     Collision
# 11                    3   Personal Auto   Personal L3          Hail
# 12                    3  Corporate Auto  Corporate L1          Hail
# 13                    8  Corporate Auto  Corporate L3          Hail
# 14                    8  Corporate Auto  Corporate L3         Other
# 15                    2  Corporate Auto  Corporate L2          Hail
# 16                    1   Personal Auto   Personal L3          Hail
# 17                    1   Personal Auto   Personal L2  Scratch/Dent
# 18                    7   Personal Auto   Personal L2          Hail
# 19                    3  Corporate Auto  Corporate L2     Collision
# 20                    1   Personal Auto   Personal L2     Collision
# 21                    1   Personal Auto   Personal L3         Other
# 22                    2   Personal Auto   Personal L3     Collision
# 23                    1  Corporate Auto  Corporate L3     Collision
# 24                    1  Corporate Auto  Corporate L2          Hail
# 25                    3   Personal Auto   Personal L3          Hail
# 26                    1   Personal Auto   Personal L3     Collision
# 27                    1  Corporate Auto  Corporate L1     Collision
# 28                    2   Personal Auto   Personal L3     Collision
# 29                    1   Personal Auto   Personal L3          Hail
# ...                 ...             ...           ...           ...
# 9104                  1   Personal Auto   Personal L2          Hail
# 9105                  3   Personal Auto   Personal L1     Collision
# 9106                  9  Corporate Auto  Corporate L3          Hail
# 9107                  1  Corporate Auto  Corporate L2          Hail
# 9108                  1   Personal Auto   Personal L2     Collision
# 9109                  1  Corporate Auto  Corporate L3     Collision
# 9110                  2   Personal Auto   Personal L2          Hail
# 9111                  1   Personal Auto   Personal L2  Scratch/Dent
# 9112                  1   Personal Auto   Personal L3  Scratch/Dent
# 9113                  1   Personal Auto   Personal L3          Hail
# 9114                  3  Corporate Auto  Corporate L1          Hail
# 9115                  2   Personal Auto   Personal L3  Scratch/Dent
# 9116                  3   Personal Auto   Personal L2     Collision
# 9117                  2   Personal Auto   Personal L1          Hail
# 9118                  3  Corporate Auto  Corporate L3     Collision
# 9119                  3  Corporate Auto  Corporate L2     Collision
# 9120                  1   Personal Auto   Personal L2  Scratch/Dent
# 9121                  1  Corporate Auto  Corporate L3     Collision
# 9122                  2   Personal Auto   Personal L2     Collision
# 9123                  3   Personal Auto   Personal L2          Hail
# 9124                  2   Personal Auto   Personal L3          Hail
# 9125                  2   Personal Auto   Personal L3     Collision
# 9126                  4  Corporate Auto  Corporate L1     Collision
# 9127                  3   Personal Auto   Personal L3          Hail
# 9128                  1   Personal Auto   Personal L2     Collision
# 9129                  2   Personal Auto   Personal L1          Hail
# 9130                  1  Corporate Auto  Corporate L3     Collision
# 9131                  2  Corporate Auto  Corporate L2     Collision
# 9132                  3   Personal Auto   Personal L2  Scratch/Dent
# 9133                  1  Corporate Auto  Corporate L3         Other
#
#       Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent          384.811147   Two-Door Car      Medsize
# 1             Agent         1131.464935  Four-Door Car      Medsize
# 2             Agent          566.472247   Two-Door Car      Medsize
# 3       Call Center          529.881344            SUV      Medsize
# 4             Agent          138.130879  Four-Door Car      Medsize
# 5               Web          159.383042   Two-Door Car      Medsize
# 6             Agent          321.600000  Four-Door Car      Medsize
# 7             Agent          363.029680  Four-Door Car      Medsize
# 8             Agent          511.200000  Four-Door Car      Medsize
# 9            Branch          425.527834  Four-Door Car      Medsize
# 10            Agent          482.400000  Four-Door Car        Small
# 11            Agent          528.000000            SUV      Medsize
# 12            Agent          472.029737  Four-Door Car      Medsize
# 13           Branch          528.000000            SUV      Medsize
# 14      Call Center          307.139132  Four-Door Car      Medsize
# 15           Branch           42.920271  Four-Door Car      Medsize
# 16      Call Center          454.245098   Two-Door Car      Medsize
# 17      Call Center          647.442031            SUV      Medsize
# 18           Branch          308.981664  Four-Door Car      Medsize
# 19      Call Center          484.800000  Four-Door Car        Small
# 20           Branch          355.200000   Two-Door Car      Medsize
# 21      Call Center          379.200000  Four-Door Car      Medsize
# 22            Agent          511.200000  Four-Door Car      Medsize
# 23           Branch          554.376763  Four-Door Car      Medsize
# 24           Branch          439.200000  Four-Door Car      Medsize
# 25      Call Center          389.185006  Four-Door Car        Large
# 26            Agent          799.200000  Four-Door Car        Small
# 27           Branch          516.237951            SUV      Medsize
# 28      Call Center          532.800000  Four-Door Car        Large
# 29           Branch          384.000000  Four-Door Car        Small
# ...             ...                 ...            ...          ...
# 9104          Agent          250.652309  Four-Door Car      Medsize
# 9105         Branch          364.800000   Two-Door Car      Medsize
# 9106          Agent          956.689634            SUV      Medsize
# 9107            Web         1027.000029            SUV      Medsize
# 9108          Agent          666.042098            SUV      Medsize
# 9109         Branch         1254.177129            SUV      Medsize
# 9110          Agent          523.200000     Sports Car      Medsize
# 9111          Agent          400.832857  Four-Door Car        Small
# 9112          Agent          165.478147            SUV      Medsize
# 9113          Agent            6.880385  Four-Door Car      Medsize
# 9114         Branch          331.170924  Four-Door Car      Medsize
# 9115    Call Center          513.600000  Four-Door Car        Small
# 9116          Agent          331.200000  Four-Door Car        Small
# 9117         Branch          185.530076   Two-Door Car      Medsize
# 9118          Agent          322.575677            SUV      Medsize
# 9119         Branch          326.400000  Four-Door Car        Small
# 9120            Web          518.400000  Four-Door Car      Medsize
# 9121         Branch          590.400000            SUV      Medsize
# 9122         Branch          465.600000  Four-Door Car        Small
# 9123          Agent          364.800000  Four-Door Car        Small
# 9124          Agent          643.200000            SUV      Medsize
# 9125          Agent         1950.725547            SUV        Small
# 9126         Branch          482.400000   Two-Door Car      Medsize
# 9127    Call Center          307.200000   Two-Door Car        Small
# 9128         Branch          541.282007  Four-Door Car        Large
# 9129            Web          198.234764  Four-Door Car      Medsize
# 9130         Branch          379.200000  Four-Door Car      Medsize
# 9131         Branch          790.784983  Four-Door Car      Medsize
# 9132         Branch          691.200000  Four-Door Car        Large
# 9133    Call Center          369.600000   Two-Door Car      Medsize
#
# [9134 rows x 26 columns]

# %%
data.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# 1                            42                          0                  8
# 2                            38                          0                  2
# 3                            65                          0                  7
# 4                            44                          0                  1
#
#       Policy Type        Policy  Claim Reason  Sales Channel  \
# 0  Corporate Auto  Corporate L3     Collision          Agent
# 1   Personal Auto   Personal L3  Scratch/Dent          Agent
# 2   Personal Auto   Personal L3     Collision          Agent
# 3  Corporate Auto  Corporate L2     Collision    Call Center
# 4   Personal Auto   Personal L1     Collision          Agent
#
#    Total Claim Amount  Vehicle Class Vehicle Size
# 0          384.811147   Two-Door Car      Medsize
# 1         1131.464935  Four-Door Car      Medsize
# 2          566.472247   Two-Door Car      Medsize
# 3          529.881344            SUV      Medsize
# 4          138.130879  Four-Door Car      Medsize
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# 9129  Bachelor           2/10/11         Employed  ...
# 9130   College           2/12/11         Employed  ...
# 9131  Bachelor            2/6/11       Unemployed  ...
# 9132   College            2/3/11         Employed  ...
# 9133   College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 9129                            89                          0
# 9130                            28                          0
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#      Number of Policies     Policy Type        Policy  Claim Reason  \
# 9129                  2   Personal Auto   Personal L1          Hail
# 9130                  1  Corporate Auto  Corporate L3     Collision
# 9131                  2  Corporate Auto  Corporate L2     Collision
# 9132                  3   Personal Auto   Personal L2  Scratch/Dent
# 9133                  1  Corporate Auto  Corporate L3         Other
#
#       Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 9129            Web          198.234764  Four-Door Car      Medsize
# 9130         Branch          379.200000  Four-Door Car      Medsize
# 9131         Branch          790.784983  Four-Door Car      Medsize
# 9132         Branch          691.200000  Four-Door Car        Large
# 9133    Call Center          369.600000   Two-Door Car      Medsize
#
# [5 rows x 26 columns]

# %%
data.dtypes
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %%
data.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %%
data.shape
# Out:
# (9134, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
# Customer                         9134 non-null object
# Country                          9134 non-null object
# State Code                       9134 non-null object
# State                            9134 non-null object
# Claim Amount                     9134 non-null float64
# Response                         9134 non-null object
# Coverage                         9134 non-null object
# Education                        9134 non-null object
# Effective To Date                9134 non-null object
# EmploymentStatus                 9134 non-null object
# Gender                           9134 non-null object
# Income                           9134 non-null int64
# Location Code                    9134 non-null object
# Marital Status                   9134 non-null object
# Monthly Premium Auto             9134 non-null int64
# Months Since Last Claim          9134 non-null int64
# Months Since Policy Inception    9134 non-null int64
# Number of Open Complaints        9134 non-null int64
# Number of Policies               9134 non-null int64
# Policy Type                      9134 non-null object
# Policy                           9134 non-null object
# Claim Reason                     9134 non-null object
# Sales Channel                    9134 non-null object
# Total Claim Amount               9134 non-null float64
# Vehicle Class                    9134 non-null object
# Vehicle Size                     9134 non-null object
# dtypes: float64(2), int64(6), object(18)
# memory usage: 1.8+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in data.columns:
    data[col] = le.fit_transform(data[col])
 
data.head()
# Out:
#    Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0       600        0           1      1           975         0         0
# 1      5946        0           3      3          4659         0         1
# 2        96        0           4      4          6900         0         2
# 3      8016        0           2      2          5140         0         0
# 4      2488        0           1      1          1058         0         0
#
#    Education  Effective To Date  EmploymentStatus  ...  \
# 0          0                 47                 1  ...
# 1          0                 24                 4  ...
# 2          0                 41                 1  ...
# 3          0                 12                 4  ...
# 4          0                 52                 1  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies  Policy Type  Policy  Claim Reason  Sales Channel  \
# 0                   0            0       2             0              0
# 1                   7            1       5             3              0
# 2                   1            1       5             0              0
# 3                   6            0       1             0              2
# 4                   0            1       3             0              0
#
#    Total Claim Amount  Vehicle Class  Vehicle Size
# 0                2941              5             1
# 1                4880              0             1
# 2                3897              5             1
# 3                3764              3             1
# 4                1138              0             1
#
# [5 rows x 26 columns]

# %%
data['Customer'].plot.box()

# %%
data['Claim Amount'].plot.box()

# %%
y = data[['Total Claim Amount']]
x = data.drop(['Total Claim Amount'], axis = 1)

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
def linreg():
    lm=LinearRegression()
    lm.fit(x,y)
    print('score=',lm.score(x,y))
    print('coefficient=',lm.coef_)
    print('Intercept=',lm.intercept_)

# %%
linreg()
# Out:
# score= 0.5609150728858984
# coefficient= [[-3.22545263e-03  6.88782364e-12  1.83247613e+00  1.83247613e+00
#    5.90625478e-03  2.27549568e+02  1.25781804e+02  1.98015826e+01
#    1.43960703e-01  1.34785018e+02  1.58166351e+02 -1.78555226e-01
#    8.39436902e+02  1.62093337e+02  1.63792068e+01 -1.40410833e+00
#   -9.22910250e-01 -5.01672106e+00 -4.17498370e+00  3.27187892e+01
#   -6.02524491e+00 -6.06320100e-01  1.46827659e+01  2.02652503e+01
#    2.41903558e+02]]
# Intercept= [995.2095393]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.90,random_state=30)

# %%
x_train.shape
# Out:
# (913, 25)

# %%
y_train.shape
# Out:
# (913, 1)

# %%
x_test.shape
# Out:
# (8221, 25)

# %%
y_test.shape
# Out:
# (8221, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([[ 8.19141070e-03, -1.54948276e-11,  1.14022943e+01,
#          1.14022943e+01,  2.30094470e-02,  6.30927568e+01,
#          1.39271829e+02,  9.78203161e+00, -2.35056275e+00,
#          1.31973516e+02,  8.50680609e+01, -1.85704522e-01,
#          8.29635821e+02,  1.09808900e+02,  1.57827054e+01,
#         -1.12706342e+00, -3.90626090e+00, -1.54092989e+01,
#         -3.49098511e+01,  1.17041317e+02, -4.69844712e+01,
#         -5.10107735e+01, -1.30016003e+01,  3.57711967e+01,
#          1.67269854e+02]])

# %%
lm.intercept_
# Out:
# array([1532.49895237])

# %%
lm.score(x_train,y_train)
# Out:
# 0.5783654018476652

# %%
pred=lm.predict(x_test)
print("predicted result",pred)
print("actual result",y_test)
# Out:
# predicted result [[2948.98608418]
#  [1921.75621076]
#  [2314.30223931]
#  ...
#  [1049.12193747]
#  [2698.93778885]
#  [3857.91757836]]
# actual result       Total Claim Amount
# 8494                2023
# 438                 1840
# 3041                2886
# 714                 4204
# 4964                5088
# 7116                3453
# 4074                2306
# 5827                3638
# 6736                4378
# 1516                5003
# 4058                2184
# 371                 4564
# 3637                3747
# 7375                2425
# 5182                3318
# 5615                3149
# 147                 2488
# 5653                1890
# 3684                2815
# 208                 3861
# 2154                4081
# 1688                2984
# 8860                4071
# 7145                2488
# 8113                3280
# 6734                2997
# 3285                4284
# 470                  683
# 2802                3289
# 4323                1589
# ...                  ...
# 1822                1241
# 6657                4451
# 2147                2902
# 4700                4036
# 1116                3724
# 3743                4312
# 3206                4210
# 4910                4233
# 779                 3409
# 3312                2595
# 8081                1655
# 8622                3289
# 6735                3249
# 4320                2501
# 2374                1948
# 3577                 715
# 3360                2629
# 8540                2542
# 4823                4022
# 4628                1484
# 7968                2799
# 6292                3982
# 5164                 438
# 3122                2416
# 177                 1826
# 56                  2357
# 3402                2705
# 4949                 358
# 1235                3754
# 3516                4481
#
# [8221 rows x 1 columns]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5418389024370255

# %%
print("error:")
print(mean_squared_error(y_test,pred))
# Out:
# error:
# 763800.5032779681

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rfr.score(x_train,y_train)
# Out:
# 0.9746990996584637

# %%
rfr=RandomForestRegressor(n_estimators=100,random_state=46)
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
# Out:
# 0.9813970104208826
